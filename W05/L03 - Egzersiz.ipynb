# %%
import pandas as pd

# %%
path = '/workspaces/A01_H05/winemag-data-130k-v2.csv'
data = pd.read_csv(path, index_col = 0)   

data
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
# Soru 1
# Asagidaki gibi bir dataframe olusturun

pd.DataFrame(data = {'Apple':[30], 'Banana':[21]})
# Out:
#    Apple  Banana
# 0     30      21

# %%
# Asagidaki data framei olusturun

pd.DataFrame(data = {'Apples':[35, 41], 'Bananas':[21, 34]}, index=['2017 Sales', '2018 Sales'])
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
# Indexleme, secme ve atama islemleri

data.head()   # ilk 5 satirini soyle bir gosterir
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
data.tail()  # son 5 datayi gosterir
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
data.columns  # butun sutunlari liste halinde getirir
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
for col in data.columns:
    print(col, end=" ")
# Out:
# country description designation points price province region_1 region_2 taster_name taster_twitter_handle title variety winery

# %%
data['country']  # bu sekilde de cagirabiliyoruz
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
data['country', 'winery']  # bu sekilde hata verir, tek boyutlu liste oldugu icin
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /workspaces/A01_H05/h05_venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('country', 'winery')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ...

# %%
data[['country', 'winery']]  # bu sekilde gelir, cift koseli parantez kullanildi indexleme oldu
# Out:
#          country                                    winery
# 0          Italy                                   Nicosia
# 1       Portugal                       Quinta dos Avidagos
# 2             US                                 Rainstorm
# 3             US                                St. Julian
# 4             US                              Sweet Cheeks
# ...          ...                                       ...
# 129966   Germany  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967        US                                  Citation
# 129968    France                           Domaine Gresser
# 129969    France                      Domaine Marcel Deiss
# 129970    France                          Domaine Schoffit
#
# [129971 rows x 2 columns]

# %%
# iloc() metodu --> veri setinden indexlemeyi sayilarla yapmayi saglar i index loc location
# loc() --> veri setinden indexlemeyi sutun etiketleriyle yapmayi saglar

data.iloc[0]  # sifirinci index satirini gosteridi
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
data.iloc[:,:]    # virgulun sol kismi satirlari dilimleme, sag kismi sutunlari dilimleme, indexleme
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
data.iloc[:,]  # bu da all oluyor
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
data.iloc[5:10,0:4]
# Out:
#                                          description   designation  points
# 5  Blackberry and raspberry aromas show a typical...  Ars In Vitro      87
# 6  Here's a bright, informal red that opens with ...       Belsito      87
# 7  This dry and restrained wine offers spice in p...           NaN      87
# 8  Savory dried thyme notes accent sunnier flavor...         Shine      87
# 9  This has great depth of flavor with its fresh ...   Les Natures      87

# %%
# Soru, data setindeinin ilk 100 - 750 arasi satirlari alin, sadece winery sutununu aliniz

data.iloc[100:750,12:13]
# Out:
#                  winery
# 100             Ventosa
# 101   Lamoreaux Landing
# 102   Lamoreaux Landing
# 103               Leyda
# 104        Madonna Alta
# ..                  ...
# 745          Ribafreixo
# 746       Jacob's Creek
# 747     William Knuttel
# 748          Casa Larga
# 749  Cave de Beblenheim
#
# [650 rows x 1 columns]

# %%
# ya da 
data.iloc[100:750,-1]
# Out:
# 100               Ventosa
# 101     Lamoreaux Landing
# 102     Lamoreaux Landing
# 103                 Leyda
# 104          Madonna Alta
#               ...
# 745            Ribafreixo
# 746         Jacob's Creek
# 747       William Knuttel
# 748            Casa Larga
# 749    Cave de Beblenheim
# Name: winery, Length: 650, dtype: object

# %%
# ya da  loc kullanarak
data.loc[100:750,'winery']
# Out:
# 100               Ventosa
# 101     Lamoreaux Landing
# 102     Lamoreaux Landing
# 103                 Leyda
# 104          Madonna Alta
#               ...
# 746         Jacob's Creek
# 747       William Knuttel
# 748            Casa Larga
# 749    Cave de Beblenheim
# 750              De Loach
# Name: winery, Length: 651, dtype: object

# %%
# ya da  loc kullanarak coklu secimde [] geldi
data.loc[100:750,['winery','country']]
# Out:
#                  winery    country
# 100             Ventosa         US
# 101   Lamoreaux Landing         US
# 102   Lamoreaux Landing         US
# 103               Leyda      Chile
# 104        Madonna Alta      Italy
# ..                  ...        ...
# 746       Jacob's Creek  Australia
# 747     William Knuttel         US
# 748          Casa Larga         US
# 749  Cave de Beblenheim     France
# 750            De Loach         US
#
# [651 rows x 2 columns]

# %%
# loc metodu ile son 75

data.loc[-75:, ['points', 'price']]   # loc ile olmuyor
# Out:
#         points  price
# 0           87    NaN
# 1           87   15.0
# 2           87   14.0
# 3           87   13.0
# 4           87   65.0
# ...        ...    ...
# 129966      90   28.0
# 129967      90   75.0
# 129968      90   30.0
# 129969      90   32.0
# 129970      90   21.0
#
# [129971 rows x 2 columns]

# %%
data.iloc[-75:, 3:5]  # iloc ile oluyor
# Out:
#         points  price
# 129896      91   36.0
# 129897      91   48.0
# 129898      91   52.0
# 129899      91   30.0
# 129900      91   32.0
# ...        ...    ...
# 129966      90   28.0
# 129967      90   75.0
# 129968      90   30.0
# 129969      90   32.0
# 129970      90   21.0
#
# [75 rows x 2 columns]

# %%
# Sarta gore indexlemeler   # bu en cok kullanilan tarz

data['country'] == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
data[data.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
data[ (data.country == 'Italy') & (data.points > 90)  ]   # burada parantez sart, olmayinca calismiyor

# bu en cok kullanilan yontemlerden biri
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# 133      Italy  Einaudi's wines have been improving lately, an...
# 135      Italy  The color is just beginning to show signs of b...
# 158      Italy  Baked plum, Asian spice, vanilla and menthol a...
# ...        ...                                                ...
# 129675   Italy  Aromas of underbrush, leather, mature berry, g...
# 129681   Italy  Ripe black-skinned berry, violet, leather and ...
# 129892   Italy  Classic Sangiovese aromas of red berry, culina...
# 129893   Italy  Aromas of passion fruit, hay and a vegetal not...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
#
#                     designation  points  price  province  \
# 120         Bricco Rocche Prapó      92   70.0  Piedmont
# ...

# %%
# ornek sarabin fiyati 10 dolardan dusuk olan ve puani 90dan buyuk olan

data[ (data.price < 10 ) & (data.points > 90)  ]
# Out:
#         country                                        description  \
# 10386        US  A marvelous effort in a difficult year, this t...
# 26101        US  With full ripeness, density and concentration,...
# 34629  Portugal  Richly tannic, this concentrated wine has grea...
# 43977        US  Kudos to Ste. Michelle for accurately labeling...
# 56988        US  This tangy, all-stainless, lightly grassy, dry...
#
#               designation  points  price    province              region_1  \
# 10386                 NaN      91    9.0  Washington  Columbia Valley (WA)
# 26101  Winemaker's Select      91    8.0  Washington  Columbia Valley (WA)
# 34629            Toutalga      91    7.0  Alentejano                   NaN
# 43977                 Dry      91    9.0  Washington  Columbia Valley (WA)
# 56988          Fumé Blanc      91    9.0  Washington  Columbia Valley (WA)
#
#               region_2   taster_name taster_twitter_handle  \
# ...

# %%
# FIN
