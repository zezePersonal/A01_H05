# %% [markdown]
# Join, Concat ile Veri Seti Birlestirme

# %%
import pandas as pd
import numpy as np

# %%
path = '/workspaces/A01_H05/winemag-data-130k-v2.csv'
df = pd.read_csv(path, index_col = 0)   

df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# Sutun rename
'''
    Eger cok kisaltma varsa, normal haliyle sutun ismi duzeltilir
    Eger cok uzunsa, 3-4 kelimeden fazla ise daha kisa bir sutun ismi secilir.
    Deger anlamini tam olarak tasmiyorsa daha anlamli haliyle degistirilir
'''

# %%
df.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
# points --> score

df.rename(columns= {'points':'scores'}, inplace=True)

# %%
df.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    scores  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
# province, region1, region2

df.rename(columns={'region_1':'normal_address','region_2':'detailed_address'}, inplace=True)

# %%
df.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    scores  price           province normal_address detailed_address  \
# 0      87    NaN  Sicily & Sardinia           Etna              NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
# Join ve Concat Islemleri
'''
    Yeni veri setleri

    veriler paylasilamadi, diger konuya geciyoruz
'''
